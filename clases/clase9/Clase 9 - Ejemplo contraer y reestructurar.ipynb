# %%
import pandas as pd

# %%
import numpy as np

# %%
# %cd 'C:\Users\magse\Dropbox\Pruebas'
# Out:
# [WinError 123] El nombre de archivo, el nombre de directorio o la sintaxis de la etiqueta del volumen no son correctos: "'C:\\Users\\magse\\Dropbox\\Pruebas'"
# C:\Users\magse\Dropbox\Pruebas

# %%
#Importar base

# %%
file = 'asesinatos_lideres.xlsx' # Creo una variable con el nombre del archivo

# %%
#pip install xlrd==1.2.0 #la ultima versión de xlrd tiene problemas importando xlsx, hay que intalar esta versión previa.

# %%
lideres = pd.read_excel(file, nrows=577, usecols='A:V')

# %%
# Explorar base y mantener variables de interés

# %%
lideres.head(10)
# Out:
#                            id                      nombre datasketch  \
# 0  francisco-jaramillo-moreno  Francisco Jaramillo Moreno         si
# 1     victor-jaramillo-moreno     Víctor Jaramillo Moreno         si
# 2      willinton-andres-banol      Willinton Andres Bañol         si
# 3        mario-alexis-tarache  Mario Alexis Tarache Perez         si
# 4        robinson-avila-ortiz        Robinson Avila Ortiz         si
# 5        senelia-regifo-gomez        Senelia Regifo Gómez        NaN
# 6          marco-aurelio-diaz          Marco Aurelio Diaz        NaN
# 7              isaias-penagos              Isaias Penagos        NaN
# 8             anibal-coronado             Aníbal Coronado        NaN
# 9                 edwin-yonda                 Edwin Yonda        NaN
#
#   pacifista ojoalapaz indepaz  onu defensoria unidaddevictimas  \
# 0       NaN       NaN      si  NaN        NaN              NaN
# 1       NaN       NaN      si  NaN        NaN              NaN
# 2       NaN       NaN      si  NaN        NaN               si
# 3       NaN        si      si  NaN        NaN              NaN
# 4       NaN        si      si  NaN        NaN              NaN
# 5       NaN       NaN      si  NaN        NaN              NaN
# 6       NaN       NaN     NaN  NaN        NaN              NaN
# 7       NaN        si      si  NaN        NaN              NaN
# 8       NaN        si      si  NaN        NaN              NaN
# 9       NaN       NaN     NaN  NaN        NaN              NaN
#
#   somosdefensores  ... colectivodeabogadosjoséalvea género      fecha  \
# 0             NaN  ...                           si      M 2016-01-02
# 1             NaN  ...                           si      M 2016-01-02
# 2              si  ...                          NaN      M 2016-01-10
# 3              si  ...                           si      M 2016-01-14
# 4             NaN  ...                           si      M 2016-01-31
# 5              si  ...                           si      F 2016-02-02
# 6              si  ...                           si      M 2016-02-06
# 7             NaN  ...                          NaN      M 2016-02-07
# 8              si  ...                           si      M 2016-02-18
# 9             NaN  ...                          NaN      M 2016-02-22
#
#               municipio departamento                tipodelíder  \
# 0               BRICENO    ANTIOQUIA  Lider campesino o agrario
# 1               BRICENO    ANTIOQUIA  Lider campesino o agrario
# 2               PEREIRA    RISARALDA          Lider comunitario
# 3  SAN LUIS DE PALENQUE     CASANARE          Lider comunitario
# 4             ALGECIRAS        HUILA          Lider comunitario
# 5        COLON Y GENOVA       NARINO             Lider sindical
# 6   EL PITAL DE CALDONO        CAUCA             Lider indigena
# 7           PUERTO ASIS     PUTUMAYO  Lider campesino o agrario
# 8        CIENAGA DE ORO      CORDOBA          Lider comunitario
# 9                  PAEZ        CAUCA             Lider indigena
#
#                                                cargo  \
# 0                                          Campesino
# 1                                          Campesino
# 2  Líder social de Galicia, y propietario de la F...
# 3  Presidente de la Junta de Acción Comunal de la...
# 4      Líder comunal del Bajo Quebradón de Algeciras
# 5                                            Docente
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                             Comunero indígena Cric
#
#                                                móvil  \
# 0  El 1 de enero de 2016 desaparecieron dos herma...
# 1  El 1 de enero de 2016 desaparecieron dos herma...
# 2  Fue hallado sin vida en zona boscosa del secto...
# 3         Le propinaron varios disparos con escopeta
# 4                 Encontrado muerto en sitio aislado
# 5  La asesinaron propinandole disparos con arma d...
# 6                                                NaN
# 7                                                NaN
# 8  El líder se dirigía a recoger a sus hijos al c...
# 9              Fue asesinado con otras dos personas.
#
#                                                otros  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Días después se capturaron los presuntos asesi...
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#                                              fuentes
# 0  http://prensarural.org/spip/spip.php?article18439
# 1  http://prensarural.org/spip/spip.php?article18439
# 2       https://vidassilenciadas.org/victimas/37812/
# 3  http://hsbnoticias.com/noticias/judicial/dos-c...
# 4  http://caracol.com.co/radio/2011/04/25/judicia...
# 5       https://vidassilenciadas.org/victimas/37817/
# 6  https://redhuerteros.org/b410&registros=10&pag...
# 7  http://justiciaypazcolombia.com/Asesinado-camp...
# 8  http://www.elespectador.com/noticias/nacional/...
# 9  https://pasocolombia.tupale.co/I2241e9d9b97414...
#
# [10 rows x 22 columns]

# %%
lideres.tail(10)
# Out:
#                              id                      nombre datasketch  \
# 567               oneida-epiayu               Oneida Epiayú         si
# 568         constantino-ramirez         Constantino Ramírez         si
# 569             miguel-ceballos             Miguel Ceballos         si
# 570             flower-trompeta             Flower Trompeta         si
# 571  neehwesx-cristina-bautista  Neehwesx Cristina Bautista         si
# 572          luis-eugenio-muñoz         Luis Eugenio Muñoz          si
# 573       jesus-eduardo-mestizo       Jesús Eduardo Mestizo         si
# 574       carlos-aldario-arenas       Carlos Aldario Arenas         si
# 575    walter-enrique-rodriguez    Walter Enrique Rodríguez         si
# 576           bernardo-de-jesus   Bernanrdo de Jesús Chancí         si
#
#     pacifista ojoalapaz indepaz  onu defensoria unidaddevictimas  \
# 567        si       NaN     NaN  NaN        NaN              NaN
# 568        si       NaN     NaN  NaN        NaN              NaN
# 569        si       NaN     NaN  NaN        NaN              NaN
# 570        si       NaN     NaN  NaN        NaN              NaN
# 571        si       NaN     NaN  NaN        NaN              NaN
# 572        si       NaN     NaN  NaN        NaN              NaN
# 573        si       NaN     NaN  NaN        NaN              NaN
# 574        si       NaN     NaN  NaN        NaN              NaN
# 575        si       NaN     NaN  NaN        NaN              NaN
# 576        si       NaN     NaN  NaN        NaN              NaN
#
#     somosdefensores  ... colectivodeabogadosjoséalvea género      fecha  \
# 567             NaN  ...                          NaN      F 2019-10-16
# 568             NaN  ...                          NaN      M 2019-10-17
# 569             NaN  ...                          NaN      M 2019-10-22
# 570             NaN  ...                          NaN      M 2019-10-28
# 571             NaN  ...                          NaN      F 2019-10-28
# 572             NaN  ...                          NaN      M 2019-11-02
# 573             NaN  ...                          NaN      M 2019-11-03
# 574             NaN  ...                          NaN      M 2019-11-09
# 575             NaN  ...                          NaN      M 2019-11-21
# 576             NaN  ...                          NaN      M 2019-11-26
#
#                municipio departamento                tipodelíder  \
# 567              MANAURE   LA GUAJIRA             Lider indigena
# 568              CALARCA      QUINDIO             Lider indigena
# 569         LA MONTANITA      CAQUETA          Lider comunitario
# 570              CORINTO        CAUCA             Lider indigena
# 571             TACUEYO         CAUCA             Lider indigena
# 572               ARABIA      PEREIRA          Lider comunitario
# 573              TORIBIO        CAUCA             Lider indigena
# 574  PARAMO SANTA ISABEL       TOLIMA  Lider campesino o agrario
# 575               TARAZA    ANTIOQUIA          Lider comunitario
# 576              ITUANGO    ANTIOQUIA          Lider comunitario
#
#                                                  cargo  \
# 567  Reconocida lideresa que venía denunciando irre...
# 568  Perteneciente al pueblo embera en Quindío, amb...
# 569  Miembro de la Junta de Acción Comunal de la zo...
# 570  Líder y comunero que trabajaba en la Asociació...
# 571           Gobernadora indígena del norte del Cauca
# 572  Fue presidente de las Juntas Administradoras L...
# 573  Comunero y líder indígena, socio fundador de l...
# 574  Reconocido líder por ser uno de los promotores...
# 575  Presidente de la Junta de Acción Comunal de la...
# 576  Presidente de la Junta de Acción Comunal de la...
#
#                                                  móvil otros  \
# 567                                                NaN   NaN
# 568  Fue atacado con arma de fuego por varios hombr...   NaN
# 569  El asesinato sucedió en la propia casa del líd...   NaN
# 570  El ejército lo presentó como integrante de la ...   NaN
# 571  El asesinato de la Gobernadora ocurrió en hora...   NaN
# 572  El crimen se registró el pasado sábado cuando ...   NaN
# 573  Según la información del CRIC, el asesinato de...   NaN
# 574  Las autoridades informaron que el hombre de 44...   NaN
# 575  El hombre de 48 años de edad fue asesinado en ...   NaN
# 576  Fue atacado con arma de fuego por tres descono...   NaN
#
#                                                fuentes
# 567  https://www.elheraldo.co/la-guajira/asesinan-b...
# 568  https://www.semana.com/nacion/articulo/constan...
# 569  https://noticias.caracoltv.com/lidera-la-vida/...
# 570  https://www.las2orillas.co/el-asesinato-del-jo...
# 571  https://boyaca.extra.com.co/noticias/judicial/...
# 572  https://www.eltiempo.com/colombia/otras-ciudad...
# 573  https://www.contagioradio.com/asesinan-a-jesus...
# 574  https://www.elespectador.com/noticias/medio-am...
# 575  https://www.lafm.com.co/colombia/nuevo-caso-de...
# 576  https://www.elespectador.com/noticias/nacional...
#
# [10 rows x 22 columns]

# %%
lideres=lideres[['nombre', 'género', 'fecha', 'municipio', 'departamento', 'tipodelíder']]

# %%
# Crear variables de mes, año y mesaño.

# %%
lideres['mesaño']=lideres['fecha'].dt.to_period('M')

# %%
lideres["año"]=lideres['fecha'].dt.year

# %%
lideres["mes"]=lideres['fecha'].dt.month

# %%
#Tabla de frecuencias - las organiza de mayor a menor frecuencia

# %%
pd.value_counts(lideres.mesaño).to_frame().reset_index()
# Out:
#       index  mesaño
# 0   2018-07      33
# 1   2018-01      29
# 2   2018-03      23
# 3   2017-01      22
# 4   2017-10      20
# 5   2018-06      20
# 6   2018-08      20
# 7   2016-12      19
# 8   2018-05      19
# 9   2018-02      17
# 10  2017-05      17
# 11  2019-01      17
# 12  2017-04      16
# 13  2016-03      16
# 14  2016-09      16
# 15  2019-09      15
# 16  2017-02      15
# 17  2016-08      14
# 18  2017-06      14
# 19  2019-05      14
# 20  2016-11      13
# 21  2016-02      11
# 22  2016-05      10
# 23  2018-11      10
# 24  2018-04       9
# 25  2016-10       9
# 26  2018-10       9
# 27  2017-08       9
# 28  2016-06       9
# 29  2016-07       8
# 30  2019-10       8
# 31  2017-07       7
# 32  2017-03       7
# 33  2017-11       7
# 34  2016-04       7
# 35  2019-04       7
# 36  2019-06       7
# 37  2017-12       7
# 38  2017-09       6
# 39  2018-12       6
# 40  2019-07       6
# 41  2019-11       5
# 42  2018-09       5
# 43  2019-03       5
# 44  2019-08       5
# 45  2016-01       5
# 46  2019-02       4

# %%
pd.value_counts(lideres.año).to_frame().reset_index()
# Out:
#    index  año
# 0   2018  200
# 1   2017  147
# 2   2016  137
# 3   2019   93

# %%
# tablas de frecuencias

# %%
pd.value_counts(lideres.departamento).to_frame().reset_index()
# Out:
#                  index  departamento
# 0                CAUCA           133
# 1            ANTIOQUIA            80
# 2               NARINO            49
# 3      VALLE DEL CAUCA            38
# 4   NORTE DE SANTANDER            37
# 5              CORDOBA            30
# 6              CAQUETA            24
# 7                CHOCO            23
# 8             PUTUMAYO            20
# 9                 META            17
# 10              ARAUCA            14
# 11          LA GUAJIRA            10
# 12               SUCRE            10
# 13             BOLIVAR             9
# 14               HUILA             8
# 15           MAGDALENA             8
# 16               CESAR             8
# 17              TOLIMA             7
# 18           ATLANTICO             7
# 19           RISARALDA             7
# 20              BOGOTA             6
# 21           SANTANDER             6
# 22        CUNDINAMARCA             5
# 23              CALDAS             5
# 24            CASANARE             5
# 25            GUAVIARE             5
# 26             QUINDIO             3
# 27             VICHADA             1
# 28              BOYACA             1
# 29             PEREIRA             1

# %%
lid_depto=pd.value_counts(lideres.departamento).to_frame().reset_index() #¿Que tipo de objeto creó? ¿Diferencias con R?

# %%
lid_depto.columns # ¿El uso de las tablas de frecuencia es mas versatil que en Stata o R?
# Out:
# Index(['index', 'departamento'], dtype='object')

# %%
lid_depto_tabla_totvar=lideres.groupby('departamento').count()

# %%
lideres['frecuencia']=np.where(lideres['nombre'].isna()=='FALSE', 0, 1) ##creo una variable para contar

# %%
lid_depto_tabla=lideres.groupby('departamento')[['frecuencia']].count() # ¿Cuál es la gran diferencia con Stata? ¿y con R?

# %%
## Crear tablas que cuenten los líderes por municipio, por mesaño, por año, por departamento y año

# %%
lid_mun_tabla=lideres.groupby('municipio')[['frecuencia']].count()

# %%
lid_mesaño_tabla=lideres.groupby('mesaño')[['frecuencia']].count()

# %%
lid_año_tabla=lideres.groupby('año')[['frecuencia']].count()

# %%
lid_depto_año_tabla=lideres.groupby(['departamento','año'])[['frecuencia']].count()

# %%
## Reestructurar tablas usando pivot y melt (parecido a R)  ## otras funciones son unstak y stack

# %%
# modificar tabla para exportar (que se pueda leer fácilmente)

# %%
lid_depto_año_tabla=lid_depto_año_tabla.reset_index() ## para cambiar la forma las variables involucradas no deben estar indexadas

# %%
lid_depto_año_tabla_ancha=lid_depto_año_tabla.pivot(index='departamento', columns='año', values='frecuencia')

# %%
# modificar tabla para analizar (Separación de variables de identificación y  medición)  - con funciones de libreria tidyr

# %%
lid_depto_año_tabla_ancha=lid_depto_año_tabla_ancha.reset_index() ## para cambiar la forma las variables involucradas no deben estar indexadas

# %%
lid_depto_año_tabla_larga=lid_depto_año_tabla_ancha.melt(id_vars='departamento', var_name='año', value_name='frecuencia')

# %%
# más estadísticas descriptivas en una tabla agregada

# %%
descriptivas_depto=lid_depto_año_tabla_larga.groupby('departamento')[['frecuencia']].agg(['mean', 'max', 'min'])

# %%
descriptivas_depto
# Out:
#                    frecuencia
#                          mean   max   min
# departamento
# ANTIOQUIA           20.000000  30.0  10.0
# ARAUCA               3.500000   9.0   1.0
# ATLANTICO            2.333333   3.0   2.0
# BOGOTA               2.000000   3.0   1.0
# BOLIVAR              2.250000   5.0   1.0
# BOYACA               1.000000   1.0   1.0
# CALDAS               2.500000   4.0   1.0
# CAQUETA              6.000000  10.0   3.0
# CASANARE             1.666667   2.0   1.0
# CAUCA               33.250000  47.0  23.0
# CESAR                2.000000   4.0   1.0
# CHOCO                5.750000  11.0   2.0
# CORDOBA              7.500000  10.0   5.0
# CUNDINAMARCA         2.500000   4.0   1.0
# GUAVIARE             1.666667   2.0   1.0
# HUILA                2.000000   3.0   1.0
# LA GUAJIRA           2.500000   3.0   2.0
# MAGDALENA            2.000000   3.0   1.0
# META                 5.666667  10.0   1.0
# NARINO              12.250000  18.0   8.0
# NORTE DE SANTANDER   9.250000  21.0   5.0
# PEREIRA              1.000000   1.0   1.0
# PUTUMAYO             5.000000  10.0   2.0
# QUINDIO              1.500000   2.0   1.0
# RISARALDA            2.333333   3.0   1.0
# SANTANDER            1.500000   2.0   1.0
# SUCRE                2.500000   5.0   1.0
# TOLIMA               1.750000   2.0   1.0
# VALLE DEL CAUCA      9.500000  14.0   5.0
# VICHADA              1.000000   1.0   1.0
