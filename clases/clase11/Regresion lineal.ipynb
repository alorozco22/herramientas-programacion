# %%
import pandas as pd
import statsmodels.api as sm
import numpy as np

# %%
# Definir directorio
# %cd "C:/Users/VEW0102/Universidad de los Andes/Alfredo Eleazar Orozco Quesada - Curso Programación para datos EdContinua/Clases"

# Importar datos
df = pd.read_excel('Implementación/Clase 11/wage2.xls')
# Out:
# C:\Users\VEW0102\Universidad de los Andes\Alfredo Eleazar Orozco Quesada - Curso Programación para datos EdContinua\Clases

# %%
print(df.head(5))
print(df.shape)
# Out:
#    wage  hours   IQ  educ  exper  tenure  age  married  black  urban meduc  \
# 0   769     40   93    12     11       2   31        1      0      1     8
# 1   808     50  119    18     11      16   37        1      0      1    14
# 2   825     40  108    14     11       9   33        1      0      1    14
# 3   650     40   96    12     13       7   32        1      0      1    12
# 4   562     40   74    11     14       5   34        1      0      1     6
#
#   feduc
# 0     8
# 1    14
# 2    14
# 3    12
# 4    11
# (935, 12)

# %%
df.describe()
# Out:
#               wage       hours          IQ        educ       exper  \
# count   935.000000  935.000000  935.000000  935.000000  935.000000
# mean    957.945455   43.929412  101.282353   13.468449   11.563636
# std     404.360822    7.224256   15.052636    2.196654    4.374586
# min     115.000000   20.000000   50.000000    9.000000    1.000000
# 25%     669.000000   40.000000   92.000000   12.000000    8.000000
# 50%     905.000000   40.000000  102.000000   12.000000   11.000000
# 75%    1160.000000   48.000000  112.000000   16.000000   15.000000
# max    3078.000000   80.000000  145.000000   18.000000   23.000000
#
#            tenure         age     married       black       urban
# count  935.000000  935.000000  935.000000  935.000000  935.000000
# mean     7.234225   33.080214    0.893048    0.128342    0.717647
# std      5.075206    3.107803    0.309217    0.334650    0.450385
# min      0.000000   28.000000    0.000000    0.000000    0.000000
# ...

# %%
#Identificando missing values
df.isnull().sum()
# Out:
# wage       0
# hours      0
# IQ         0
# educ       0
# exper      0
# tenure     0
# age        0
# married    0
# black      0
# urban      0
# meduc      0
# feduc      0
# dtype: int64

# %%
#Estdísticas descriptivas por grupo
df.groupby('married').mean()
# Out:
#                wage      hours          IQ       educ      exper    tenure  \
# married
# 0        798.440000  43.250000  101.920000  13.840000  10.220000  6.170000
# 1        977.047904  44.010778  101.205988  13.423952  11.724551  7.361677
#
#               age     black     urban
# married
# 0        32.12000  0.180000  0.770000
# 1        33.19521  0.122156  0.711377

# %%
#Estdísticas descriptivas por grupo y para una variable
df.groupby('married').educ.mean()
# Out:
# married
# 0    13.840000
# 1    13.423952
# Name: educ, dtype: float64

# %%
#Tabla de frecuencias
a=pd.crosstab(df['educ'], columns='count')
print(a)
# Out:
# col_0  count
# educ
# 9         10
# 10        35
# 11        43
# 12       393
# 13        85
# 14        77
# 15        45
# 16       150
# 17        40
# 18        57

# %%
#Tabla de frecuencias de doble entrada
a=pd.crosstab(df['educ'], columns=df['black'])
print(a)
# Out:
# black    0   1
# educ
# 9        6   4
# 10      26   9
# 11      34   9
# 12     330  63
# 13      77   8
# 14      66  11
# 15      40   5
# 16     141   9
# 17      39   1
# 18      56   1

# %%
#Coeficiente de correlación
df.corr()
# Out:
#              wage     hours        IQ      educ     exper    tenure       age  \
# wage     1.000000 -0.009504  0.309088  0.327109  0.002190  0.128266  0.156702
# hours   -0.009504  1.000000  0.073839  0.091009 -0.062126 -0.055528  0.024812
# IQ       0.309088  0.073839  1.000000  0.515697 -0.224913  0.042159 -0.043741
# educ     0.327109  0.091009  0.515697  1.000000 -0.455573 -0.036167 -0.012254
# exper    0.002190 -0.062126 -0.224913 -0.455573  1.000000  0.243654  0.495330
# tenure   0.128266 -0.055528  0.042159 -0.036167  0.243654  1.000000  0.270602
# age      0.156702  0.024812 -0.043741 -0.012254  0.495330  0.270602  1.000000
# married  0.136583  0.032563 -0.014668 -0.058566  0.106349  0.072605  0.106980
# black   -0.210878 -0.107850 -0.387869 -0.179457  0.055849 -0.078236 -0.035646
# urban    0.198406  0.016573  0.038936  0.072151 -0.047386 -0.038486 -0.006749
#
#           married     black     urban
# wage     0.136583 -0.210878  0.198406
# ...

# %%
#Regresión
mod = sm.OLS.from_formula('wage ~ 1 + educ + exper + married + tenure', data=df)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   wage   R-squared:                       0.165
# Model:                            OLS   Adj. R-squared:                  0.161
# Method:                 Least Squares   F-statistic:                     45.79
# Date:                Tue, 18 May 2021   Prob (F-statistic):           3.87e-35
# Time:                        14:51:09   Log-Likelihood:                -6854.3
# No. Observations:                 935   AIC:                         1.372e+04
# Df Residuals:                     930   BIC:                         1.374e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   -426.1507    110.596     -3.853      0.000    -643.197    -209.104
# ...
